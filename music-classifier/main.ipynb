# %% [markdown]
# # Music Classifier

# %% [markdown]
# [Source](https://www.geeksforgeeks.org/music-genre-classifier-using-machine-learning/)

# %%
#Imports

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import librosa.display

# %%
music_data = pd.read_csv('file.csv') 
music_data.head(5)
# Out:
#           filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1  blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2  blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3  blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4  blues.00004.wav  661794          0.308526         0.087841  0.091529
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002827             1784.165850          129774.064525
# 1  0.002373             1530.176679          375850.073649
# 2  0.002746             1552.811865          156467.643368
# 3  0.006346             1070.106615          184355.942417
# 4  0.002303             1835.004266          343399.939274
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              2002.449060            85882.761315  ...   52.420910
# ...

# %%
music_data['label'].value_counts()

print(np.__version__)
# Out:
# 2.1.1

# %%
path = 'genres_original/blues/blues.00000.wav'
plt.figure(figsize=(14, 5)) 
x, sr = librosa.load(path) 
librosa.display.waveplot(x, sr=sr) 
id.Audio(path) 

print("Blue")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 3
#       1 path = 'genres_original/blues/blues.00000.wav'
#       2 plt.figure(figsize=(14, 5))
# ----> 3 x, sr = librosa.load(path)
#       4 librosa.display.waveplot(x, sr=sr)
#       5 id.Audio(path)
#
# File c:\Python312\Lib\site-packages\lazy_loader\__init__.py:83, in attach.<locals>.__getattr__(name)
#      81 submod_path = f"{package_name}.{attr_to_modules[name]}"
#      82 submod = importlib.import_module(submod_path)
# ---> 83 attr = getattr(submod, name)
#      85 # If the attribute lives in a file (module) with the same
#      86 # name as the attribute, ensure that the attribute and *not*
#      87 # the module is accessible on the package.
#      88 if name == attr_to_modules[name]:
#
# File c:\Python312\Lib\site-packages\lazy_loader\__init__.py:82, in attach.<locals>.__getattr__(name)
# ...
